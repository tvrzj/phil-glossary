# %%
import pandas as pd
from bs4 import BeautifulSoup
import numpy as np
import requests

# %%
url = 'https://en.wikipedia.org/wiki/Glossary_of_philosophy'
response = requests.get(url)

soup = BeautifulSoup(response.content, "html.parser")
tags = soup.find_all("dt", class_="glossary")

# %%
concepts = [x.text.strip() for x in tags]

# %%
len(concepts)
# Out:
# 344

# %%
cz_concepts = ["absolutismus",
 "absurdismus",
 "akcidentalismus",
 "akosmismus",
 "estetismus",
 "agnostický ateismus",
 "agnostický teismus",
 "agnosticismus",
 "altruismus",
 "amor fati",
 "anarchismus",
 "anarchokapitalismus",
 "anarchoprimitivismus",
 "anarchosyndikalismus",
 "anima mundi",
 "animismus",
 "antropocentrismus",
 "antropomorfismus",
 "antinatalismus",
 "antinomismus",
 "antirealismus",
 "aristotelismus",
 "arminianismus",
 "askeze",
 "askripticismus",
 "asociativismus",
 "ateismus",
 "atomismus",
 "autoritářství",
 "automatismus",
 "behavioralismus",
 "behaviorismus",
 "biologismus",
 "buddhismus",
 "kapitalismus",
 "kariérismus",
 "kartezianismus",
 "křesťanský existenciální humanismus",
 "křesťanský existencialismus",
 "křesťanský humanismus",
 "křesťanský materialismus",
 "křesťanství",
 "klasický teismus",
 "klasicismus",
 "kognitivismus",
 "koherentismus",
 "kolbertismus",
 "kolektivismus",
 "komunismus (disambiguace)",
 "komunismus",
 "komunitarismus",
 "kompatibilismus",
 "komunismus",
 'konceptualismus',
 "vědomí",
 "konfucianismus",
 "konsekvencionalismus",
 "konstruktivismus",
 "konzumerismus",
 "kontextualismus",
 "konvencionalismus",
 "kosmoteismus",
 "kreacionismus",
 "kritický racionalismus",
 "kritický realismus",
 "cynismus",
 "darwinismus",
 "denní kreacionismus",
 "dekonstruktivismus",
 "deduktivismus",
 "defétismus",
 "deismus",
 "demokratický transhumanismus",
 "deontologismus",
 "deskriptivismus",
 "determinismus",
 "dialektický materialismus",
 "dialetheismus",
 "disjunktivismus",
 "distributismus",
 "dogma",
 "dualismus",
 "dynamismus",
 "eklekticismus",
 "rovnostářství","egoismus","eliminační materialismus","emanacionismus","emergentní materialismus","emocionalismus","emotivismus","empirismus","osvícený absolutismus","environmentalismus","epikureismus","epistemologie","epifenomenalismus","rovnostářství","esencialismus","eternalismus","etický egoismus","etnocentrismus","eudaimonismus","evoluční kreacionismus","existencialismus","experiencialismus","experimentalizmus","expresionismus","expresivismus","externalismus","externismus","extropianismus","fallibilismus","falzifikovatelnost","fašismus","feminismus","fatalismus","fideismus","finalismus","formalismus","fundamentalismus","francouzský materialismus","freudismus","funkcionalismus","kreacionismus mezer","německý idealismus","globální majetek","gnosticismus","chamtivý redukcionismus","hédonismus","hegelianismus","henoteismus","hereditářství","hinduismus","historický determinismus","historický materialismus","historismus","holismus","humanismus","humanistický naturalismus","hylozoismus","idealismus","ignosticismus","iluzionismus","imaterialismus","imoralismus","immortalismus","inkompatibilismus","indeterminismus","individualismus","indukcionismus","induktivismus","infinitismus","innatismus","instrumentalismus","intelektualismus","internalismus","intencionalismus","interakcionismus","interbehaviorismus","interpretativismus","právní interpretivismus","intrinsicismus","intuicionismus","iracionalismus","irealismu", "islamismus",
 "džinismus",
 "jansenismus",
 "judaismus",
 "kantovství",
 "kathenoteismus",
 "kierkegaardianismus",
 "legalismus",
 "právní interpretivismus",
 "právní naturalismus",
 "právní pozitivismus",
 "liberalismus",
 "libertarianismus",
 "jazykový relativismus",
 "logický atomismus",
 "logický behaviorismus",
 "logický pozitivismus",
 "logicismus",
 "manicheismus",
 "marxismus",
 "materialismus",
 "mazdaismus",
 "mechanismus",
 "meliorismus",
 "mentalismus",
 "metafyzický naturalismus",
 "metafyzika",
 "metodologický behaviorismus",
 "metodologický naturalismus",
 "metodologický redukcionismus",
 "metodologický relativismus",
 "modální realismus",
 "modernismus",
 "mohismus",
 "molinismus",
 "monismus",
 "monistický teismus",
 "monolatrismus",
 "monoteismus",
 "morální absolutismus",
 "morální realismus",
 "morální relativismus",
 "morální univerzalismus",
 "mysticismus",
 "naivní realismus",
 "nativismus",
 "naturalismus",
 "necessitarianismus",
 "neokonfucianismus",
 "neomarxismus",
 "neoplatonismus",
 "nový konfucianismus",
 "nihilismus",
 "nominalismus",
 "nonkognitivismus",
 "nontheismus",
 "objektivní idealismus",
 "objektivismus",
 "příležitostný",
 "kreacionismus staré Země",
 "omfaloský kreacionismus",
 "ontologický redukcionismus",
 "ontologismus",
 "otevřený teismus",
 "operacionalismus",
 "optimismus",
 "organicismus",
 "ortokratismus",
 "pacifismus",
 "pankritický racionalismus",
 "pandeismus",
 "panenteismus",
 "panpsychismus",
 "panteismus",
 "partikularismus",
 "pelagianismus",
 "perfekcionismus",
 "personalismus",
 "perspektivismus",
 "pesimismus",
 "fenomenální konzervatismus",
 "fenomenalismus",
 "filozofický teismus",
 "filosofie",
 "fyzikalismus",
 "platónský realismus",
 "platonismus",
 "pluralismus",
 "politický absolutismus",
 "polylogismus",
 "polyteismus",
 "pozitivismus",
 "poststrukturalismus",
 "posthumanismus",
 "postmodernismus",
 "pragmatismus",
 "preskriptivismus",
 "probabilismus",
 "psychologický behaviorismus",
 "psychologický egoismus",
 "psychologismus",
 "pyrrhonský skepticismus",
 "pyrrhonismus",
 "pythagoreismus",
 "kvazirealismus",
 "Qualia",
 "radikální behaviorismus",
 "randianismus",
 "racionalismus",
 "realismus",
 "rekonstruktivismus",
 "redukcionismus",
 "reduktivní materialismus",
 "relacionalismus",
 "relativismus",
 "reliabilismus",
 "náboženský humanismus",
 "reprezentativismus",
 "romantismus",
 "scholastika",
 "vědecký redukcionismus",
 "scientismus",
 "skotismus",
 "sekulární humanismus",
 "sekularismus",
 "sikhismus",
 "semipelagianismus",
 "sensualismus",
 "singularitarismus",
 "situacionalismus",
 "skepticismus",
 "sociální atomismus",
 "sociální darwinismus",
 "socialismus",
 "solipsismus",
 "sofismus",
 "speciesismus",
 "spiritualismus",
 "etatismus",
 "stoicismus",
 "silný agnosticismus",
 "silný ateismus",
 "strukturalismus",
 "subjektivní idealismus",
 "subjektivismus",
 "substanční dualismus",
 "substanční monoteismus",
 "substancialismus",
 "surrealismus",
 "symbolismus",
 "synkretismus",
 "taoismus",
 "teleologický behaviorismus",
 "teleologismus",
 "teismus",
 "teologický nonkognitivismus",
 "tomismus",
 "totalitarismus",
 "transcendentální idealismus",
 "transcendentalismus",
 "transhumanismus",
 "transteismus",
 "pravda",
 "tvrzení pravdy",
 "univerzalismus",
 "utilitarismus",
 "utopismus",
 "hodnotový pluralismus",
 "verifikacionismus",
 "vitalismus",
 "voluntarismus",
 "dobrovolnictví",
 "slabý agnosticismus",
 "slabý ateismus",
 "kreacionismus mladé Země",
 "youthismus",
 "zenový buddhismus",
 "zoroastrismus"]

# %%
len(cz_concepts)
# Out:
# 344

# %%
data = {
    'english' : concepts,
    'czech' : cz_concepts
}
dictionary_df = pd.DataFrame(data, columns=['english', 'czech'])

# %%
dictionary_df
# Out:
#                                                 0
# absolutismus                           absolutism
# absurdismus                             absurdism
# akcidentalismus                     accidentalism
# akosmismus                               acosmism
# estetismus                           aestheticism
# ...                                           ...
# slabý ateismus                       weak atheism
# kreacionismus mladé Země  Young Earth creationism
# youthismus                               youthism
# zenový buddhismus                    Zen Buddhism
# zoroastrismus                      Zoroastrianism
#
# [344 rows x 1 columns]

# %%
#reducing concepts from 343 to 200
rows_to_remove = np.random.choice(len(dictionary_df), 144, replace=False)

dic_filtered = dictionary_df.drop(rows_to_remove)

dic_filtered.reset_index(drop=True, inplace=True)

dic_filtered
# Out:
#               english                czech
# 0          absolutism         absolutismus
# 1           absurdism          absurdismus
# 2            acosmism           akosmismus
# 3        aestheticism           estetismus
# 4     agnostic theism   agnostický teismus
# ..                ...                  ...
# 195          vitalism           vitalismus
# 196  weak agnosticism  slabý agnosticismus
# 197          youthism           youthismus
# 198      Zen Buddhism    zenový buddhismus
# 199    Zoroastrianism        zoroastrismus
#
# [200 rows x 2 columns]

# %%
dictionary_df.to_csv('dictionary.csv')
dic_filtered.to_csv('dictionary_filtered.csv')
